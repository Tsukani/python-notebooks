# %% [markdown]
# # Class Exercise
# 1. If not allready done register on OpenWetherMap and get an api key: https://home.openweathermap.org/api_keys
# 2. get the 5 day forecast data like this:
# ```python
# url = "http://api.openweathermap.org/data/2.5/forecast"
# req = requests.get(url, params={'q': 'Copenhagen,dk', 'mode': 'json',
#                                 'units': 'metric',
#                                 'appid': api_keys.OWM_API_KEY})
#
# req_json = json.loads(req.text)
# ```
# 3. create a function to get 'main' data from each list item in the forecast
# 4. find the lowest and highest temperature in celcius from the 5 days forecast
#
# ### City data
# 5. Download list of all cities here: http://bulk.openweathermap.org/sample/city.list.json.gz and unzip it
# 6. read the file and use json.load(file_name) to load the data into a dict
# 7. create a function to return a dict of key=countryname and value= list of all available cities
# 8. how many cities are in DK
# 9. create a function that returns a dictionary with avg temperatures of all cities provided in a list
# 10. what is the temperatur difference between Los Angeles and Copenhagen?

# %%
import requests
import json
url = "http://api.openweathermap.org/data/2.5/forecast"
req = requests.get(url, params={
    'q': 'Copenhagen,dk', 'mode': 'json', 
    'units': 'metric', 
    'appid': "f7db6ae9b7eb32bfef5585dad56fc47e" #Don't steal my API key, please :^))))))))
})

#req_json = json.loads(req.text)
req.json()
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1668697200,
#    'main': {'temp': 5.73,
#     'feels_like': 0.18,
#     'temp_min': 5.73,
#     'temp_max': 6.11,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 1006,
#     'humidity': 69,
#     'temp_kf': -0.38},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 20},
#    'wind': {'speed': 11.55, 'deg': 103, 'gust': 15.58},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-11-17 15:00:00'},
#   {'dt': 1668708000,
#    'main': {'temp': 5.86,
#     'feels_like': 0.39,
#     'temp_min': 5.86,
#     'temp_max': 6.11,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 1007,
#     'humidity': 67,
#     'temp_kf': -0.25},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 16},
#    'wind': {'speed': 11.38, 'deg': 106, 'gust': 15.55},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-17 18:00:00'},
#   {'dt': 1668718800,
#    'main': {'temp': 6.01,
#     'feels_like': 0.8,
#     'temp_min': 6.01,
#     'temp_max': 6.15,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 1007,
#     'humidity': 65,
#     'temp_kf': -0.14},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 14},
#    'wind': {'speed': 10.52, 'deg': 104, 'gust': 14.61},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-17 21:00:00'},
#   {'dt': 1668729600,
#    'main': {'temp': 6.34,
#     'feels_like': 1.52,
#     'temp_min': 6.34,
#     'temp_max': 6.34,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 1008,
#     'humidity': 62,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 11},
#    'wind': {'speed': 9.41, 'deg': 100, 'gust': 12.86},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-18 00:00:00'},
#   {'dt': 1668740400,
#    'main': {'temp': 5.9,
#     'feels_like': 1.01,
#     'temp_min': 5.9,
#     'temp_max': 5.9,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 1008,
#     'humidity': 72,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 9.15, 'deg': 89, 'gust': 12.69},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-18 03:00:00'},
#   {'dt': 1668751200,
#    'main': {'temp': 5.67,
#     'feels_like': 0.64,
#     'temp_min': 5.67,
#     'temp_max': 5.67,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1010,
#     'humidity': 69,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 9.39, 'deg': 94, 'gust': 12.98},
#    'visibility': 10000,
#    'pop': 0.33,
#    'rain': {'3h': 0.25},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-18 06:00:00'},
#   {'dt': 1668762000,
#    'main': {'temp': 6.19,
#     'feels_like': 1.22,
#     'temp_min': 6.19,
#     'temp_max': 6.19,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 1012,
#     'humidity': 53,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 9.78, 'deg': 91, 'gust': 11.93},
#    'visibility': 10000,
#    'pop': 0.3,
#    'rain': {'3h': 0.14},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-11-18 09:00:00'},
#   {'dt': 1668772800,
#    'main': {'temp': 6.12,
#     'feels_like': 1.61,
#     'temp_min': 6.12,
#     'temp_max': 6.12,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1013,
#     'humidity': 54,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 63},
#    'wind': {'speed': 8.07, 'deg': 79, 'gust': 10.83},
#    'visibility': 10000,
#    'pop': 0.02,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-11-18 12:00:00'},
#   {'dt': 1668783600,
#    'main': {'temp': 5.33,
#     'feels_like': 0.79,
#     'temp_min': 5.33,
#     'temp_max': 5.33,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1014,
#     'humidity': 58,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 97},
#    'wind': {'speed': 7.41, 'deg': 66, 'gust': 9.42},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-18 15:00:00'},
#   {'dt': 1668794400,
#    'main': {'temp': 4.08,
#     'feels_like': -0.71,
#     'temp_min': 4.08,
#     'temp_max': 4.08,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1015,
#     'humidity': 60,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 93},
#    'wind': {'speed': 7.1, 'deg': 57, 'gust': 9.13},
#    'visibility': 10000,
#    'pop': 0.14,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-18 18:00:00'},
#   {'dt': 1668805200,
#    'main': {'temp': 3.26,
#     'feels_like': -1.8,
#     'temp_min': 3.26,
#     'temp_max': 3.26,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1015,
#     'humidity': 63,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 17},
#    'wind': {'speed': 7.19, 'deg': 47, 'gust': 9.36},
#    'visibility': 10000,
#    'pop': 0.15,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-18 21:00:00'},
#   {'dt': 1668816000,
#    'main': {'temp': 2.77,
#     'feels_like': -2.31,
#     'temp_min': 2.77,
#     'temp_max': 2.77,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1015,
#     'humidity': 71,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 17},
#    'wind': {'speed': 6.9, 'deg': 40, 'gust': 9.4},
#    'visibility': 10000,
#    'pop': 0.07,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-19 00:00:00'},
#   {'dt': 1668826800,
#    'main': {'temp': 2.51,
#     'feels_like': -2.69,
#     'temp_min': 2.51,
#     'temp_max': 2.51,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1015,
#     'humidity': 73,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 18},
#    'wind': {'speed': 7.01, 'deg': 43, 'gust': 9.5},
#    'visibility': 10000,
#    'pop': 0.01,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-19 03:00:00'},
#   {'dt': 1668837600,
#    'main': {'temp': 2.04,
#     'feels_like': -2.85,
#     'temp_min': 2.04,
#     'temp_max': 2.04,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1015,
#     'humidity': 77,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 25},
#    'wind': {'speed': 5.98, 'deg': 38, 'gust': 8.55},
#    'visibility': 10000,
#    'pop': 0.01,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-19 06:00:00'},
#   {'dt': 1668848400,
#    'main': {'temp': 2.21,
#     'feels_like': -2.18,
#     'temp_min': 2.21,
#     'temp_max': 2.21,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1014,
#     'humidity': 76,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 64},
#    'wind': {'speed': 5.06, 'deg': 21, 'gust': 7.05},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-11-19 09:00:00'},
#   {'dt': 1668859200,
#    'main': {'temp': 3.08,
#     'feels_like': -1.31,
#     'temp_min': 3.08,
#     'temp_max': 3.08,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 1012,
#     'humidity': 68,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 82},
#    'wind': {'speed': 5.5, 'deg': 4, 'gust': 6.65},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-11-19 12:00:00'},
#   {'dt': 1668870000,
#    'main': {'temp': 1.65,
#     'feels_like': -1.81,
#     'temp_min': 1.65,
#     'temp_max': 1.65,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1011,
#     'humidity': 90,
#     'temp_kf': 0},
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.36, 'deg': 354, 'gust': 4.82},
#    'visibility': 3788,
#    'pop': 0.37,
#    'snow': {'3h': 0.15},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-19 15:00:00'},
#   {'dt': 1668880800,
#    'main': {'temp': 1.3,
#     'feels_like': -0.99,
#     'temp_min': 1.3,
#     'temp_max': 1.3,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1009,
#     'humidity': 96,
#     'temp_kf': 0},
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.04, 'deg': 348, 'gust': 3.06},
#    'visibility': 73,
#    'pop': 0.95,
#    'snow': {'3h': 1.05},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-19 18:00:00'},
#   {'dt': 1668891600,
#    'main': {'temp': 1.34,
#     'feels_like': 1.34,
#     'temp_min': 1.34,
#     'temp_max': 1.34,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 1008,
#     'humidity': 91,
#     'temp_kf': 0},
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 0.33, 'deg': 9, 'gust': 1.4},
#    'visibility': 2243,
#    'pop': 0.86,
#    'snow': {'3h': 0.49},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-19 21:00:00'},
#   {'dt': 1668902400,
#    'main': {'temp': 1.59,
#     'feels_like': 1.59,
#     'temp_min': 1.59,
#     'temp_max': 1.59,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 1007,
#     'humidity': 85,
#     'temp_kf': 0},
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 0.65, 'deg': 243, 'gust': 1.36},
#    'visibility': 9187,
#    'pop': 0.69,
#    'snow': {'3h': 0.31},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-20 00:00:00'},
#   {'dt': 1668913200,
#    'main': {'temp': 1.38,
#     'feels_like': -0.48,
#     'temp_min': 1.38,
#     'temp_max': 1.38,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 1006,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 92},
#    'wind': {'speed': 1.71, 'deg': 248, 'gust': 2.03},
#    'visibility': 10000,
#    'pop': 0.11,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-20 03:00:00'},
#   {'dt': 1668924000,
#    'main': {'temp': 1.45,
#     'feels_like': -1.68,
#     'temp_min': 1.45,
#     'temp_max': 1.45,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 1006,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 92},
#    'wind': {'speed': 2.91, 'deg': 244, 'gust': 3.9},
#    'visibility': 10000,
#    'pop': 0.09,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-20 06:00:00'},
#   {'dt': 1668934800,
#    'main': {'temp': 2.34,
#     'feels_like': -0.91,
#     'temp_min': 2.34,
#     'temp_max': 2.34,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 1006,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 98},
#    'wind': {'speed': 3.28, 'deg': 224, 'gust': 4.8},
#    'visibility': 10000,
#    'pop': 0.25,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-11-20 09:00:00'},
#   {'dt': 1668945600,
#    'main': {'temp': 3.1,
#     'feels_like': -0.26,
#     'temp_min': 3.1,
#     'temp_max': 3.1,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 1006,
#     'humidity': 73,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 97},
#    'wind': {'speed': 3.67, 'deg': 226, 'gust': 4.84},
#    'visibility': 10000,
#    'pop': 0.37,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-11-20 12:00:00'},
#   {'dt': 1668956400,
#    'main': {'temp': 2.82,
#     'feels_like': -0.13,
#     'temp_min': 2.82,
#     'temp_max': 2.82,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 1006,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 92},
#    'wind': {'speed': 3.02, 'deg': 214, 'gust': 4.71},
#    'visibility': 10000,
#    'pop': 0.05,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-20 15:00:00'},
#   {'dt': 1668967200,
#    'main': {'temp': 3.12,
#     'feels_like': -0.43,
#     'temp_min': 3.12,
#     'temp_max': 3.12,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 1006,
#     'humidity': 64,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 84},
#    'wind': {'speed': 3.96, 'deg': 162, 'gust': 5.52},
#    'visibility': 10000,
#    'pop': 0.05,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-20 18:00:00'},
#   {'dt': 1668978000,
#    'main': {'temp': 3.87,
#     'feels_like': -0.51,
#     'temp_min': 3.87,
#     'temp_max': 3.87,
#     'pressure': 1006,
#     'sea_level': 1006,
#     'grnd_level': 1005,
#     'humidity': 60,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 98},
#    'wind': {'speed': 5.94, 'deg': 151, 'gust': 8.25},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-20 21:00:00'},
#   {'dt': 1668988800,
#    'main': {'temp': 4.37,
#     'feels_like': 0.06,
#     'temp_min': 4.37,
#     'temp_max': 4.37,
#     'pressure': 1006,
#     'sea_level': 1006,
#     'grnd_level': 1005,
#     'humidity': 73,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 6.09, 'deg': 151, 'gust': 8.57},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-21 00:00:00'},
#   {'dt': 1668999600,
#    'main': {'temp': 5.85,
#     'feels_like': 1.52,
#     'temp_min': 5.85,
#     'temp_max': 5.85,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 1003,
#     'humidity': 79,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 7.26, 'deg': 155, 'gust': 9.85},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-21 03:00:00'},
#   {'dt': 1669010400,
#    'main': {'temp': 6.14,
#     'feels_like': 1.73,
#     'temp_min': 6.14,
#     'temp_max': 6.14,
#     'pressure': 1004,
#     'sea_level': 1004,
#     'grnd_level': 1003,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 7.76, 'deg': 163, 'gust': 10.08},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-21 06:00:00'},
#   {'dt': 1669021200,
#    'main': {'temp': 7.05,
#     'feels_like': 2.99,
#     'temp_min': 7.05,
#     'temp_max': 7.05,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 1004,
#     'humidity': 80,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 7.48, 'deg': 180, 'gust': 9.71},
#    'visibility': 10000,
#    'pop': 0.31,
#    'rain': {'3h': 0.58},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-11-21 09:00:00'},
#   {'dt': 1669032000,
#    'main': {'temp': 7.53,
#     'feels_like': 3.47,
#     'temp_min': 7.53,
#     'temp_max': 7.53,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 1004,
#     'humidity': 73,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 7.97, 'deg': 173, 'gust': 9.78},
#    'visibility': 10000,
#    'pop': 0.28,
#    'rain': {'3h': 0.22},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-11-21 12:00:00'},
#   {'dt': 1669042800,
#    'main': {'temp': 7.57,
#     'feels_like': 3.67,
#     'temp_min': 7.57,
#     'temp_max': 7.57,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 1004,
#     'humidity': 69,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 7.47, 'deg': 172, 'gust': 9.6},
#    'visibility': 10000,
#    'pop': 0.2,
#    'rain': {'3h': 0.12},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-21 15:00:00'},
#   {'dt': 1669053600,
#    'main': {'temp': 7.59,
#     'feels_like': 3.98,
#     'temp_min': 7.59,
#     'temp_max': 7.59,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 1004,
#     'humidity': 74,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 6.58, 'deg': 171, 'gust': 8.96},
#    'visibility': 10000,
#    'pop': 0.2,
#    'rain': {'3h': 0.22},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-21 18:00:00'},
#   {'dt': 1669064400,
#    'main': {'temp': 7.54,
#     'feels_like': 3.89,
#     'temp_min': 7.54,
#     'temp_max': 7.54,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 1004,
#     'humidity': 75,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 6.65, 'deg': 156, 'gust': 8.49},
#    'visibility': 10000,
#    'pop': 0.32,
#    'rain': {'3h': 0.4},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-21 21:00:00'},
#   {'dt': 1669075200,
#    'main': {'temp': 7.31,
#     'feels_like': 4.04,
#     'temp_min': 7.31,
#     'temp_max': 7.31,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 1004,
#     'humidity': 72,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.45, 'deg': 156, 'gust': 7.64},
#    'visibility': 10000,
#    'pop': 0.37,
#    'rain': {'3h': 0.21},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-22 00:00:00'},
#   {'dt': 1669086000,
#    'main': {'temp': 7.24,
#     'feels_like': 3.85,
#     'temp_min': 7.24,
#     'temp_max': 7.24,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 1004,
#     'humidity': 72,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.7, 'deg': 135, 'gust': 7.68},
#    'visibility': 10000,
#    'pop': 0.3,
#    'rain': {'3h': 0.29},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-22 03:00:00'},
#   {'dt': 1669096800,
#    'main': {'temp': 6.94,
#     'feels_like': 3.16,
#     'temp_min': 6.94,
#     'temp_max': 6.94,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 1004,
#     'humidity': 75,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 6.54, 'deg': 121, 'gust': 8.58},
#    'visibility': 10000,
#    'pop': 0.22,
#    'rain': {'3h': 0.37},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-11-22 06:00:00'},
#   {'dt': 1669107600,
#    'main': {'temp': 6.71,
#     'feels_like': 2.91,
#     'temp_min': 6.71,
#     'temp_max': 6.71,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 1006,
#     'humidity': 74,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 6.41, 'deg': 115, 'gust': 8.35},
#    'visibility': 10000,
#    'pop': 0.5,
#    'rain': {'3h': 0.51},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-11-22 09:00:00'},
#   {'dt': 1669118400,
#    'main': {'temp': 6.7,
#     'feels_like': 2.94,
#     'temp_min': 6.7,
#     'temp_max': 6.7,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 1005,
#     'humidity': 71,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 6.31, 'deg': 101, 'gust': 7.49},
#    'visibility': 10000,
#    'pop': 0.32,
#    'rain': {'3h': 0.14},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-11-22 12:00:00'}],
#  'city': {'id': 2618425,
#   'name': 'Copenhagen',
#   'coord': {'lat': 55.6759, 'lon': 12.5655},
#   'country': 'DK',
#   'population': 15000,
#   'timezone': 3600,
#   'sunrise': 1668667709,
#   'sunset': 1668697267}}

# %% [markdown]
# # Handin Exercise 6
#
# Create a module containing a class: TextComparer with the following methods:
# 1. `__init__(self, url_list)`
# 2. `download(url,filename)` that stores the file on disk and raises NotFoundException when url returns 404
# 3. `multi_download()` uses threads to download multiple urls as text and stores filenames on a property of the TextComparer class object (Hint: use the download() method and create the filenames from the url or from the response object)
# 4. `__iter__()` returns an iterator
# 5. `__next__()` returns the next filename (and stops when there are no more)
# 6. `urllist_generator()` returns a generator to loop through the urls
# 7. `avg_vowels(text)` - a rough estimate on readability returns average number of vowels in the words of the text
# 8. `hardest_read()` reads all text from files in `filenames` and returns the filename of the text with the highest vowel score (use all the cpu cores on the computer for this work.
#
# ### Ex 2
# Create a notebook and import your module from above
# 1. Find 10 books on https://www.gutenberg.org/browse/scores/top and download them using an object of the class you just created before
# 2. Test the different methods of your class
# 3. Make a bar plot with a sorted list of books on x-axis and avg vowels on y-axis
